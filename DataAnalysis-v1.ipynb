# %%
import pandas
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, PowerTransformer, Normalizer
import os
import glob
import re

# %% [markdown]
# ## Checking up the idle current readings for reference

# %%
# Find the idle power consumption with and without Fan and no perf running
# i.e. # Idleworkload-MaxFan and 

def __get_stats__(path:str,field_prefix:str) -> pandas.DataFrame:
    freqs=[]
    ampere_mA_mean = []
    watt_mW_mean = []
    idle_datafname  = re.compile(r'.*CPUFreq\-([.\d]+)GHz')
    _idle_results_maxfan_bcore = glob.glob(path)
    ctr = 0
    for freqstepdata in _idle_results_maxfan_bcore:
        fname_match = idle_datafname.match(freqstepdata)
        if (fname_match):
            # print (freqstepdata + ': '+fname_match.group(1))
            freqidlepd = pandas.read_csv(freqstepdata+'/Idling.powdata.csv')
            freqidlepd.drop(columns=['utctime.1', 'ts_utc'], inplace=True)
            freqidlepd['dev_ippwr-ch1-volts_mV'] = freqidlepd['dev_ippwr-ch1-volts_mV'].apply(lambda x: float(x[2:-1]) if isinstance(x, str) and x.startswith("b'") else x)
            freqidlepd['dev_ippwr-ch1-ampere_mA'] = freqidlepd['dev_ippwr-ch1-ampere_mA'].apply(lambda x: float(x[2:-1]) if isinstance(x, str) and x.startswith("b'") else x)
            freqidlepd['dev_ippwr-ch1-watt_mW'] = freqidlepd['dev_ippwr-ch1-watt_mW'].apply(lambda x: float(x[2:-1]) if isinstance(x, str) and x.startswith("b'") else x)

            df2_mean = freqidlepd[["dev_ippwr-ch1-ampere_mA","dev_ippwr-ch1-watt_mW","therm_cpu0","therm_cpu1", "therm_cpu2", "therm_cpu4"]].mean()
            df2_median = freqidlepd[["dev_ippwr-ch1-ampere_mA","dev_ippwr-ch1-watt_mW","therm_cpu0","therm_cpu1", "therm_cpu2", "therm_cpu4"]].median()
            # display(freqidlepd)
            freqs.append(float(fname_match.group(1)))
            ampere_mA_mean.append(df2_mean["dev_ippwr-ch1-ampere_mA"])
            watt_mW_mean.append(df2_mean["dev_ippwr-ch1-watt_mW"])

            # print (str(freqs[ctr])+': '+str(ampere_mA_mean[ctr])+', '+str(ampere_mA_median[ctr])+', '+str(watt_mW_mean[ctr])+', '+str(watt_mW_median[ctr]))
            
        else:
            # print ('No match for: '+ freqstepdata)
            pass
        ctr += 1
    df = pandas.DataFrame(list(zip(freqs, ampere_mA_mean, watt_mW_mean)),
                        columns =['Frequency', field_prefix+'ampere_mA_mean', field_prefix+'watt_mW_mean'])
    return df    

def calculate_power_impacts():
    ###########################################################################
    # Compile the Big Core idling current data
    df_maxfan_bigcore = __get_stats__('combined_dataset-2/01-Simple-Idling/MaxFan/*-BigCore-*','MaxFan_')
    df_maxfan_bigcore.sort_values('Frequency', inplace=True)
    # df_maxfan.index= df_maxfan['Frequency']

    df_nofan_bigcore = __get_stats__('combined_dataset-2/01-Simple-Idling/NoFan/*-BigCore-*','NoFan_')
    df_nofan_bigcore.sort_values('Frequency', inplace=True)
    # df_nofan.index= df_nofan['Frequency']

    newdf_bigcore= pandas.merge(left=df_maxfan_bigcore, right=df_nofan_bigcore, on='Frequency' )
    newdf_bigcore.sort_values('Frequency', inplace=True)

    ###########################################################################
    # Compile the Lttle Core idling current data
    df_maxfan_littlecore = __get_stats__('combined_dataset/01-Simple-Idling/MaxFan/*-LittleCore-*','MaxFan_')
    df_maxfan_littlecore.sort_values('Frequency', inplace=True)
    # df_maxfan.index= df_maxfan['Frequency']

    df_nofan_littlecore = __get_stats__('combined_dataset/01-Simple-Idling/NoFan/*-LittleCore-*','NoFan_')
    df_nofan_littlecore.sort_values('Frequency', inplace=True)
    # df_nofan.index= df_nofan['Frequency']

    newdf_littlecore = pandas.merge(left=df_maxfan_littlecore, right=df_nofan_littlecore, on='Frequency' )
    newdf_littlecore.sort_values('Frequency', inplace=True)

    ###########################################################################
    # Calculate the power consumption by Fan
    df_bigcore_fandiff = newdf_bigcore['MaxFan_ampere_mA_mean'] - newdf_bigcore['NoFan_ampere_mA_mean']
    df_litcore_fandiff = newdf_littlecore['MaxFan_ampere_mA_mean'] - newdf_littlecore['NoFan_ampere_mA_mean']
    fan_delta = (df_bigcore_fandiff.describe()['mean'] + df_litcore_fandiff.describe()['mean'])/2
    print ('Current consumption impact on fan = '+ str(fan_delta) +' mA')

    df_bigcore_fandiff = newdf_bigcore['MaxFan_watt_mW_mean'] - newdf_bigcore['NoFan_watt_mW_mean']
    df_litcore_fandiff = newdf_littlecore['MaxFan_watt_mW_mean'] - newdf_littlecore['NoFan_watt_mW_mean']
    fan_delta = (df_bigcore_fandiff.describe()['mean'] + df_litcore_fandiff.describe()['mean'])/2
    print ('Power consumption impact on fan = '+ str(fan_delta) +' mW')
    ###########################################################################
    # Calculate the Power difference between each frequency ranges in idling
    # df_bigcore_freqdiff = newdf_bigcore.diff()
    display(newdf_bigcore[['Frequency','NoFan_watt_mW_mean']])

# %% [markdown]
# ## Processing workloads data

# %%
def process_workload_data(filename:str):
    pd_bzip2_enwik8 = pandas.read_csv(filename)

    pd_bzip2_enwik8['dev_ippwr-ch1-volts_mV'] = pd_bzip2_enwik8['dev_ippwr-ch1-volts_mV'].apply(lambda x: float(x[2:-1]) if isinstance(x, str) and x.startswith("b'") else x)
    pd_bzip2_enwik8['dev_ippwr-ch1-ampere_mA'] = pd_bzip2_enwik8['dev_ippwr-ch1-ampere_mA'].apply(lambda x: float(x[2:-1]) if isinstance(x, str) and x.startswith("b'") else x)
    pd_bzip2_enwik8['dev_ippwr-ch1-watt_mW'] = pd_bzip2_enwik8['dev_ippwr-ch1-watt_mW'].apply(lambda x: float(x[2:-1]) if isinstance(x, str) and x.startswith("b'") else x)

    ### JUGAAD WARNING :) ### 
    # Jugaad method of deducing earlier power estimations of idle power at each frequency and fan consumption
    # pd_bzip2_enwik8['dev_ippwr-ch1-watt_mW'] = pd_bzip2_enwik8['dev_ippwr-ch1-watt_mW'] - 2761.181154 - 409.6397807531478

    pd_bzip2_enwik8.drop(pd_bzip2_enwik8.columns.difference([
        'utctime',
        'dev_ippwr-ch1-volts_mV','dev_ippwr-ch1-ampere_mA','dev_ippwr-ch1-watt_mW',
        'S0-D0-C0_cpu-cycles','S0-D0-C0_instructions','S0-D0-C0_cache-misses', 'S0-D0-C0_cache-references', 'S0-D0-C0_branch-instructions', 'S0-D0-C0_branch-misses', 'S0-D0-C0_branch-load-misses', 'S0-D0-C0_branch-loads',
        'S0-D0-C1_cpu-cycles','S0-D0-C1_instructions','S0-D0-C1_cache-misses', 'S0-D0-C1_cache-references', 'S0-D0-C1_branch-instructions', 'S0-D0-C1_branch-misses', 'S0-D0-C1_branch-load-misses', 'S0-D0-C1_branch-loads',
        'S0-D0-C2_cpu-cycles','S0-D0-C2_instructions','S0-D0-C2_cache-misses', 'S0-D0-C2_cache-references', 'S0-D0-C2_branch-instructions', 'S0-D0-C2_branch-misses', 'S0-D0-C2_branch-load-misses', 'S0-D0-C2_branch-loads',
        'S0-D0-C3_cpu-cycles','S0-D0-C3_instructions','S0-D0-C3_cache-misses', 'S0-D0-C3_cache-references', 'S0-D0-C3_branch-instructions', 'S0-D0-C3_branch-misses', 'S0-D0-C3_branch-load-misses', 'S0-D0-C3_branch-loads',
        'S1-D0-C0_cpu-cycles','S1-D0-C0_instructions','S1-D0-C0_cache-misses', 'S1-D0-C0_cache-references', 'S1-D0-C0_branch-instructions', 'S1-D0-C0_branch-misses', 'S1-D0-C0_branch-load-misses', 'S1-D0-C0_branch-loads',
        'S1-D0-C1_cpu-cycles','S1-D0-C1_instructions','S1-D0-C1_cache-misses', 'S1-D0-C1_cache-references', 'S1-D0-C1_branch-instructions', 'S1-D0-C1_branch-misses', 'S1-D0-C1_branch-load-misses', 'S1-D0-C1_branch-loads',
        'S1-D0-C2_cpu-cycles','S1-D0-C2_instructions','S1-D0-C2_cache-misses', 'S1-D0-C2_cache-references', 'S1-D0-C2_branch-instructions', 'S1-D0-C2_branch-misses', 'S1-D0-C2_branch-load-misses', 'S1-D0-C2_branch-loads',
        'S1-D0-C3_cpu-cycles','S1-D0-C3_instructions','S1-D0-C3_cache-misses', 'S1-D0-C3_cache-references', 'S1-D0-C3_branch-instructions', 'S1-D0-C3_branch-misses', 'S1-D0-C3_branch-load-misses', 'S1-D0-C3_branch-loads',
        ]), axis=1, inplace=True)

    ## Per core CPI/IPC & Misc. calculation for little cores
    # S0-D0-C0 - Little Core #1
    pd_bzip2_enwik8['S0-D0-C0_CPI'] = pd_bzip2_enwik8['S0-D0-C0_cpu-cycles']/pd_bzip2_enwik8['S0-D0-C0_instructions']  
    pd_bzip2_enwik8['S0-D0-C0_IPC'] = 1/pd_bzip2_enwik8['S0-D0-C0_CPI']
    pd_bzip2_enwik8['S0-D0-C0_CacheMissRatio'] = pd_bzip2_enwik8['S0-D0-C0_cache-misses']  / pd_bzip2_enwik8['S0-D0-C0_cache-references']

    # S0-D0-C1 - Little Core #2
    pd_bzip2_enwik8['S0-D0-C1_CPI'] = pd_bzip2_enwik8['S0-D0-C1_cpu-cycles']/pd_bzip2_enwik8['S0-D0-C1_instructions']
    pd_bzip2_enwik8['S0-D0-C1_IPC'] = 1/pd_bzip2_enwik8['S0-D0-C1_CPI']
    pd_bzip2_enwik8['S0-D0-C1_CacheMissRatio'] = pd_bzip2_enwik8['S0-D0-C1_cache-misses']  / pd_bzip2_enwik8['S0-D0-C1_cache-references']

    # S0-D0-C2 - Little Core #3
    pd_bzip2_enwik8['S0-D0-C2_CPI'] = pd_bzip2_enwik8['S0-D0-C2_cpu-cycles']/pd_bzip2_enwik8['S0-D0-C2_instructions']
    pd_bzip2_enwik8['S0-D0-C2_IPC'] = 1/pd_bzip2_enwik8['S0-D0-C2_CPI']
    pd_bzip2_enwik8['S0-D0-C2_CacheMissRatio'] = pd_bzip2_enwik8['S0-D0-C2_cache-misses']  / pd_bzip2_enwik8['S0-D0-C2_cache-references']

    # S0-D0-C3 - Little Core #4
    pd_bzip2_enwik8['S0-D0-C3_CPI'] = pd_bzip2_enwik8['S0-D0-C3_cpu-cycles']/pd_bzip2_enwik8['S0-D0-C3_instructions']
    pd_bzip2_enwik8['S0-D0-C3_IPC'] = 1/pd_bzip2_enwik8['S0-D0-C3_CPI']
    pd_bzip2_enwik8['S0-D0-C3_CacheMissRatio'] = pd_bzip2_enwik8['S0-D0-C3_cache-misses'] / pd_bzip2_enwik8['S0-D0-C3_cache-references']

    ## Per core CPI/IPC & Misc. calculation for Big cores
    # S1-D0-C0 - Big Core #1
    pd_bzip2_enwik8['S1-D0-C0_CPI'] = pd_bzip2_enwik8['S1-D0-C0_cpu-cycles']/pd_bzip2_enwik8['S1-D0-C0_instructions']
    pd_bzip2_enwik8['S1-D0-C0_IPC'] = 1/pd_bzip2_enwik8['S1-D0-C0_CPI']
    pd_bzip2_enwik8['S1-D0-C0_CacheMissRatio'] = pd_bzip2_enwik8['S1-D0-C0_cache-misses']  / pd_bzip2_enwik8['S1-D0-C0_cache-references']

    # S1-D0-C1 - Big Core #2
    pd_bzip2_enwik8['S1-D0-C1_CPI'] = pd_bzip2_enwik8['S1-D0-C1_cpu-cycles']/pd_bzip2_enwik8['S1-D0-C1_instructions']
    pd_bzip2_enwik8['S1-D0-C1_IPC'] = 1/pd_bzip2_enwik8['S1-D0-C1_CPI']
    pd_bzip2_enwik8['S1-D0-C1_CacheMissRatio'] = pd_bzip2_enwik8['S1-D0-C1_cache-misses']  / pd_bzip2_enwik8['S1-D0-C1_cache-references']

    # S1-D0-C2 - Big Core #3
    pd_bzip2_enwik8['S1-D0-C2_CPI'] = pd_bzip2_enwik8['S1-D0-C2_cpu-cycles']/pd_bzip2_enwik8['S1-D0-C2_instructions']
    pd_bzip2_enwik8['S1-D0-C2_IPC'] = 1/pd_bzip2_enwik8['S1-D0-C2_CPI']
    pd_bzip2_enwik8['S1-D0-C2_CacheMissRatio'] = pd_bzip2_enwik8['S1-D0-C2_cache-misses'] / pd_bzip2_enwik8['S1-D0-C2_cache-references']

    # S1-D0-C3 - Big Core #4
    pd_bzip2_enwik8['S1-D0-C3_CPI'] = pd_bzip2_enwik8['S1-D0-C3_cpu-cycles']/pd_bzip2_enwik8['S1-D0-C3_instructions']
    pd_bzip2_enwik8['S1-D0-C3_IPC'] = 1/pd_bzip2_enwik8['S1-D0-C3_CPI']
    pd_bzip2_enwik8['S1-D0-C3_CacheMissRatio'] = pd_bzip2_enwik8['S1-D0-C3_cache-misses'] / pd_bzip2_enwik8['S1-D0-C3_cache-references']

    # Drop all the NA data points
    pd_bzip2_enwik8 = pd_bzip2_enwik8.dropna()

    ## Obtain the aggregate numbers for cluster and chip for CPI
    collist_cpi = ['S0-D0-C0_CPI', 'S0-D0-C1_CPI', 'S0-D0-C2_CPI', 'S0-D0-C3_CPI']
    collist_ipc = ['S1-D0-C0_CPI', 'S1-D0-C1_CPI', 'S1-D0-C2_CPI', 'S1-D0-C3_CPI']
    pd_bzip2_enwik8['Aggregate_CPI-Little'] = pd_bzip2_enwik8[collist_cpi].sum(axis=1)
    pd_bzip2_enwik8['Aggregate_CPI-Big'] = pd_bzip2_enwik8[collist_ipc].sum(axis=1)
    pd_bzip2_enwik8['Aggregate_CPI'] = pd_bzip2_enwik8[['Aggregate_CPI-Little', 'Aggregate_CPI-Big']].sum(axis=1)

    ## Obtain the aggregate numbers for cluster and chip for IPC
    collist = ['S0-D0-C0_IPC', 'S0-D0-C1_IPC', 'S0-D0-C2_IPC', 'S0-D0-C3_IPC']
    collist = ['S1-D0-C0_IPC', 'S1-D0-C1_IPC', 'S1-D0-C2_IPC', 'S1-D0-C3_IPC']
    pd_bzip2_enwik8['Aggregate_IPC-Little'] = pd_bzip2_enwik8[collist].sum(axis=1)
    pd_bzip2_enwik8['Aggregate_IPC-Big'] = pd_bzip2_enwik8[collist].sum(axis=1)
    pd_bzip2_enwik8['Aggregate_IPC'] = pd_bzip2_enwik8[['Aggregate_IPC-Little','Aggregate_IPC-Big']].sum(axis=1)

    ## Obtain the aggregate numbers for cluster and chip for Cache miss ratio
    collist_cmrat_little = ['S1-D0-C0_CacheMissRatio','S1-D0-C1_CacheMissRatio', 'S1-D0-C2_CacheMissRatio','S1-D0-C3_CacheMissRatio']
    collist_cmrat_big = ['S0-D0-C0_CacheMissRatio','S0-D0-C1_CacheMissRatio', 'S0-D0-C2_CacheMissRatio','S0-D0-C3_CacheMissRatio']
    pd_bzip2_enwik8['Aggregate_CacheMissRatio-Big'] = pd_bzip2_enwik8[collist_cmrat_big].sum(axis=1)
    pd_bzip2_enwik8['Aggregate_CacheMissRatio-Little'] = pd_bzip2_enwik8[collist_cmrat_little].sum(axis=1)
    pd_bzip2_enwik8['Aggregate_CacheMissRatio'] = pd_bzip2_enwik8[['Aggregate_CacheMissRatio-Little','Aggregate_CacheMissRatio-Big']].sum(axis=1)

    # Compose final data frame with Aggregate IPC
    cols = ['dev_ippwr-ch1-watt_mW','Aggregate_IPC']
    __pd_bzip2_enwik8 = pd_bzip2_enwik8[cols]
    __pd_bzip2_enwik8= __pd_bzip2_enwik8.sort_values('dev_ippwr-ch1-watt_mW')

    # Normalize the final data frame to appropriately scale the values
    scaler = Normalizer()
    df_scaled = scaler.fit_transform(__pd_bzip2_enwik8.to_numpy())
    df_scaled = pandas.DataFrame(df_scaled, columns=cols)

    correlation = df_scaled.corrwith(df_scaled['dev_ippwr-ch1-watt_mW']).sort_values(ascending=False)
    # display (correlation["Aggregate_IPC"])
    return correlation["Aggregate_IPC"]

# %%
freq_regex  = re.compile(r'.*CPUFreq\-([.\d]+)GHz')
frequency=[]
testset=[]
correlation=[]
dirs_collection = glob.glob('combined_dataset-2/03-Workloads/*')
dirs_collection_len = len (dirs_collection)
ctr = 0
for dirs in dirs_collection:
    freqval_match = freq_regex.match(dirs)
    if (freqval_match):
        print ('Processing ('+str(ctr+1)+'/'+str(dirs_collection_len)+'): '+freqval_match.group(1)+'GHz data... ')
        dataset_collection = glob.glob(dirs+'/*.csv')
        for data in dataset_collection:
            frequency.append(freqval_match.group(1))
            testset.append(os.path.basename(data))
            corr = process_workload_data(data)
            correlation.append(corr)
            
    else:
        print ('Error in frequency identification for '+dirs)
    ctr += 1

df = pandas.DataFrame(list(zip(frequency, testset, correlation)),
                    columns =['Frequency(GHz)','Data', 'correlation'])
pandas.set_option('display.max_rows', df.shape[0]+1)
print ("Correlation Result summary:")
display(df.describe())

print ("Correlation Results:")
display(df)
# Out:
# Processing (1/32): 0.4GHz data...
# Processing (2/32): 1.5GHz data...
# Processing (3/32): 1.2GHz data...
# Processing (4/32): 0.5GHz data...
# Processing (5/32): 0.3GHz data...
# Processing (6/32): 1.4GHz data...
# Processing (7/32): 0.8GHz data...
# Processing (8/32): 0.4GHz data...
# Processing (9/32): 0.7GHz data...
# Processing (10/32): 2.0GHz data...
# Processing (11/32): 1.4GHz data...
# Processing (12/32): 1.1GHz data...
# Processing (13/32): 1.7GHz data...
# Processing (14/32): 0.7GHz data...
# Processing (15/32): 1.1GHz data...
# Processing (16/32): 1.9GHz data...
# Processing (17/32): 0.6GHz data...
# Processing (18/32): 1.3GHz data...
# Processing (19/32): 0.3GHz data...
# Processing (20/32): 0.9GHz data...
# Processing (21/32): 0.5GHz data...
# Processing (22/32): 0.8GHz data...
# Processing (23/32): 1.8GHz data...
# Processing (24/32): 1.3GHz data...
# Processing (25/32): 0.9GHz data...
# Processing (26/32): 1.2GHz data...
# Processing (27/32): 0.6GHz data...
# Processing (28/32): 1.0GHz data...
# Processing (29/32): 0.2GHz data...
# Processing (30/32): 1.6GHz data...
# Processing (31/32): 1.0GHz data...
# Processing (32/32): 0.2GHz data...
# Correlation Result summary:
#        correlation
# count   715.000000
# mean     -0.936316
# std       0.043304
# min      -0.997982
# 25%      -0.967652
# 50%      -0.938532
# 75%      -0.913957
# max      -0.665649
# Correlation Results:
#     Frequency(GHz)                         Data  correlation
# 0              0.4   stress-io1-100s-1.prof.csv    -0.933979
# 1              0.4      bzip2-enwik8-1.prof.csv    -0.942343
# 2              0.4  stress-cpu1-100s-1.prof.csv    -0.902005
# 3              0.4  stress-cpu4-100s-1.prof.csv    -0.919271
# 4              0.4   stress-io3-100s-1.prof.csv    -0.927533
# 5              0.4   stress-io4-100s-1.prof.csv    -0.911440
# 6              0.4       gzip-enwik8-1.prof.csv    -0.954223
# 7              0.4     bzip2-webster-1.prof.csv    -0.956563
# 8              0.4   stress-io2-100s-1.prof.csv    -0.915228
# 9              0.4  stress-cpu3-100s-1.prof.csv    -0.864435
# 10             0.4  stress-cpu2-100s-1.prof.csv    -0.913337
# 11             0.4      gzip-webster-1.prof.csv    -0.942485
# 12             0.4       ffmpeg-360p-1.prof.csv    -0.875526
# 13             1.5      bzip2-enwik8-2.prof.csv    -0.967879
# 14             1.5     bzip2-webster-2.prof.csv    -0.937099
# 15             1.5   stress-io1-100s-1.prof.csv    -0.903217
# 16             1.5      bzip2-enwik8-1.prof.csv    -0.954696
# 17             1.5      gzip-webster-2.prof.csv    -0.984845
# 18             1.5  stress-cpu3-100s-2.prof.csv    -0.893584
# 19             1.5  stress-cpu1-100s-1.prof.csv    -0.888376
# 20             1.5       gzip-enwik8-2.prof.csv    -0.974782
# 21             1.5       ffmpeg-360p-2.prof.csv    -0.896342
# 22             1.5  stress-cpu4-100s-1.prof.csv    -0.932119
# 23             1.5   stress-io2-100s-2.prof.csv    -0.941978
# 24             1.5   stress-io3-100s-1.prof.csv    -0.893055
# 25             1.5   stress-io4-100s-1.prof.csv    -0.928165
# 26             1.5   stress-io4-100s-2.prof.csv    -0.921064
# 27             1.5       gzip-enwik8-1.prof.csv    -0.955693
# 28             1.5  stress-cpu2-100s-2.prof.csv    -0.941963
# 29             1.5  stress-cpu4-100s-2.prof.csv    -0.918556
# 30             1.5     bzip2-webster-1.prof.csv    -0.964735
# 31             1.5   stress-io3-100s-2.prof.csv    -0.921236
# 32             1.5   stress-io2-100s-1.prof.csv    -0.914159
# 33             1.5   stress-io1-100s-2.prof.csv    -0.887440
# 34             1.5  stress-cpu3-100s-1.prof.csv    -0.924863
# 35             1.5  stress-cpu2-100s-1.prof.csv    -0.894549
# 36             1.5      gzip-webster-1.prof.csv    -0.964994
# 37             1.5       ffmpeg-360p-1.prof.csv    -0.886378
# 38             1.5  stress-cpu1-100s-2.prof.csv    -0.957208
# 39             1.2      bzip2-enwik8-2.prof.csv    -0.911237
# 40             1.2     bzip2-webster-2.prof.csv    -0.985112
# 41             1.2   stress-io1-100s-1.prof.csv    -0.963907
# 42             1.2      bzip2-enwik8-1.prof.csv    -0.928922
# 43             1.2      gzip-webster-2.prof.csv    -0.995224
# 44             1.2  stress-cpu3-100s-2.prof.csv    -0.972774
# 45             1.2  stress-cpu1-100s-1.prof.csv    -0.948083
# 46             1.2       gzip-enwik8-2.prof.csv    -0.976637
# 47             1.2       ffmpeg-360p-2.prof.csv    -0.791914
# 48             1.2  stress-cpu4-100s-1.prof.csv    -0.969441
# 49             1.2   stress-io2-100s-2.prof.csv    -0.992150
# 50             1.2   stress-io3-100s-1.prof.csv    -0.988880
# 51             1.2   stress-io4-100s-1.prof.csv    -0.991123
# 52             1.2   stress-io4-100s-2.prof.csv    -0.953246
# 53             1.2       gzip-enwik8-1.prof.csv    -0.983035
# 54             1.2  stress-cpu2-100s-2.prof.csv    -0.961873
# 55             1.2  stress-cpu4-100s-2.prof.csv    -0.939243
# 56             1.2     bzip2-webster-1.prof.csv    -0.948971
# 57             1.2   stress-io3-100s-2.prof.csv    -0.994667
# 58             1.2   stress-io2-100s-1.prof.csv    -0.967493
# 59             1.2   stress-io1-100s-2.prof.csv    -0.984500
# 60             1.2  stress-cpu3-100s-1.prof.csv    -0.936479
# 61             1.2  stress-cpu2-100s-1.prof.csv    -0.941101
# 62             1.2      gzip-webster-1.prof.csv    -0.997743
# 63             1.2       ffmpeg-360p-1.prof.csv    -0.842015
# 64             1.2  stress-cpu1-100s-2.prof.csv    -0.927072
# 65             0.5   stress-io1-100s-1.prof.csv    -0.992456
# 66             0.5      bzip2-enwik8-1.prof.csv    -0.919648
# 67             0.5  stress-cpu1-100s-1.prof.csv    -0.987592
# 68             0.5  stress-cpu4-100s-1.prof.csv    -0.988659
# 69             0.5   stress-io3-100s-1.prof.csv    -0.986133
# 70             0.5   stress-io4-100s-1.prof.csv    -0.977954
# 71             0.5       gzip-enwik8-1.prof.csv    -0.902691
# 72             0.5     bzip2-webster-1.prof.csv    -0.986042
# 73             0.5   stress-io2-100s-1.prof.csv    -0.903134
# 74             0.5  stress-cpu3-100s-1.prof.csv    -0.981781
# 75             0.5  stress-cpu2-100s-1.prof.csv    -0.953834
# 76             0.5      gzip-webster-1.prof.csv    -0.994015
# 77             0.5       ffmpeg-360p-1.prof.csv    -0.760807
# 78             0.3   stress-io1-100s-1.prof.csv    -0.918565
# 79             0.3      bzip2-enwik8-1.prof.csv    -0.903453
# 80             0.3  stress-cpu1-100s-1.prof.csv    -0.890537
# 81             0.3  stress-cpu4-100s-1.prof.csv    -0.929669
# 82             0.3   stress-io3-100s-1.prof.csv    -0.921647
# 83             0.3   stress-io4-100s-1.prof.csv    -0.897921
# 84             0.3       gzip-enwik8-1.prof.csv    -0.916725
# 85             0.3     bzip2-webster-1.prof.csv    -0.952845
# 86             0.3   stress-io2-100s-1.prof.csv    -0.896667
# 87             0.3  stress-cpu3-100s-1.prof.csv    -0.916743
# 88             0.3  stress-cpu2-100s-1.prof.csv    -0.889283
# 89             0.3      gzip-webster-1.prof.csv    -0.987501
# 90             0.3       ffmpeg-360p-1.prof.csv    -0.850689
# 91             1.4      bzip2-enwik8-2.prof.csv    -0.961028
# 92             1.4     bzip2-webster-2.prof.csv    -0.933853
# 93             1.4   stress-io1-100s-1.prof.csv    -0.964923
# 94             1.4      bzip2-enwik8-1.prof.csv    -0.973742
# 95             1.4      gzip-webster-2.prof.csv    -0.972032
# 96             1.4  stress-cpu3-100s-2.prof.csv    -0.908496
# 97             1.4  stress-cpu1-100s-1.prof.csv    -0.886476
# 98             1.4       gzip-enwik8-2.prof.csv    -0.955861
# 99             1.4       ffmpeg-360p-2.prof.csv    -0.886559
# 100            1.4  stress-cpu4-100s-1.prof.csv    -0.912333
# 101            1.4   stress-io2-100s-2.prof.csv    -0.924233
# 102            1.4   stress-io3-100s-1.prof.csv    -0.909633
# 103            1.4   stress-io4-100s-1.prof.csv    -0.923997
# 104            1.4   stress-io4-100s-2.prof.csv    -0.939861
# 105            1.4       gzip-enwik8-1.prof.csv    -0.962960
# 106            1.4  stress-cpu2-100s-2.prof.csv    -0.922442
# 107            1.4  stress-cpu4-100s-2.prof.csv    -0.893868
# 108            1.4     bzip2-webster-1.prof.csv    -0.957842
# 109            1.4   stress-io3-100s-2.prof.csv    -0.911967
# 110            1.4   stress-io2-100s-1.prof.csv    -0.911775
# 111            1.4   stress-io1-100s-2.prof.csv    -0.888202
# 112            1.4  stress-cpu3-100s-1.prof.csv    -0.870202
# 113            1.4  stress-cpu2-100s-1.prof.csv    -0.932453
# 114            1.4      gzip-webster-1.prof.csv    -0.980552
# 115            1.4       ffmpeg-360p-1.prof.csv    -0.905223
# 116            1.4  stress-cpu1-100s-2.prof.csv    -0.926868
# 117            0.8      bzip2-enwik8-2.prof.csv    -0.924869
# 118            0.8     bzip2-webster-2.prof.csv    -0.967154
# 119            0.8   stress-io1-100s-1.prof.csv    -0.993111
# 120            0.8      bzip2-enwik8-1.prof.csv    -0.976732
# 121            0.8      gzip-webster-2.prof.csv    -0.994959
# 122            0.8  stress-cpu3-100s-2.prof.csv    -0.909503
# 123            0.8  stress-cpu1-100s-1.prof.csv    -0.957395
# 124            0.8       gzip-enwik8-2.prof.csv    -0.986477
# 125            0.8       ffmpeg-360p-2.prof.csv    -0.842997
# 126            0.8  stress-cpu4-100s-1.prof.csv    -0.941183
# 127            0.8   stress-io2-100s-2.prof.csv    -0.991681
# 128            0.8   stress-io3-100s-1.prof.csv    -0.988829
# 129            0.8   stress-io4-100s-1.prof.csv    -0.964013
# 130            0.8   stress-io4-100s-2.prof.csv    -0.991520
# 131            0.8       gzip-enwik8-1.prof.csv    -0.944037
# 132            0.8  stress-cpu2-100s-2.prof.csv    -0.941301
# 133            0.8  stress-cpu4-100s-2.prof.csv    -0.950275
# 134            0.8     bzip2-webster-1.prof.csv    -0.979899
# 135            0.8   stress-io3-100s-2.prof.csv    -0.986102
# 136            0.8   stress-io2-100s-1.prof.csv    -0.989230
# 137            0.8   stress-io1-100s-2.prof.csv    -0.980215
# 138            0.8  stress-cpu3-100s-1.prof.csv    -0.922158
# 139            0.8  stress-cpu2-100s-1.prof.csv    -0.977980
# 140            0.8      gzip-webster-1.prof.csv    -0.976287
# 141            0.8       ffmpeg-360p-1.prof.csv    -0.831711
# 142            0.8  stress-cpu1-100s-2.prof.csv    -0.905539
# 143            0.4   stress-io1-100s-1.prof.csv    -0.988470
# 144            0.4      bzip2-enwik8-1.prof.csv    -0.914794
# 145            0.4  stress-cpu1-100s-1.prof.csv    -0.985654
# 146            0.4  stress-cpu4-100s-1.prof.csv    -0.908069
# 147            0.4   stress-io3-100s-1.prof.csv    -0.992850
# 148            0.4   stress-io4-100s-1.prof.csv    -0.991689
# 149            0.4       gzip-enwik8-1.prof.csv    -0.936936
# 150            0.4     bzip2-webster-1.prof.csv    -0.899417
# 151            0.4   stress-io2-100s-1.prof.csv    -0.978146
# 152            0.4  stress-cpu3-100s-1.prof.csv    -0.924402
# 153            0.4  stress-cpu2-100s-1.prof.csv    -0.891967
# 154            0.4      gzip-webster-1.prof.csv    -0.935073
# 155            0.4       ffmpeg-360p-1.prof.csv    -0.721526
# 156            0.7      bzip2-enwik8-2.prof.csv    -0.927135
# 157            0.7     bzip2-webster-2.prof.csv    -0.944012
# 158            0.7   stress-io1-100s-1.prof.csv    -0.889998
# 159            0.7      bzip2-enwik8-1.prof.csv    -0.924136
# 160            0.7      gzip-webster-2.prof.csv    -0.962621
# 161            0.7  stress-cpu3-100s-2.prof.csv    -0.919648
# 162            0.7  stress-cpu1-100s-1.prof.csv    -0.896078
# 163            0.7       gzip-enwik8-2.prof.csv    -0.924601
# 164            0.7       ffmpeg-360p-2.prof.csv    -0.867303
# 165            0.7  stress-cpu4-100s-1.prof.csv    -0.907657
# 166            0.7   stress-io2-100s-2.prof.csv    -0.949248
# 167            0.7   stress-io3-100s-1.prof.csv    -0.945392
# 168            0.7   stress-io4-100s-1.prof.csv    -0.943884
# 169            0.7   stress-io4-100s-2.prof.csv    -0.952534
# 170            0.7       gzip-enwik8-1.prof.csv    -0.947081
# 171            0.7  stress-cpu2-100s-2.prof.csv    -0.950488
# 172            0.7  stress-cpu4-100s-2.prof.csv    -0.877356
# 173            0.7     bzip2-webster-1.prof.csv    -0.944810
# 174            0.7   stress-io3-100s-2.prof.csv    -0.950771
# 175            0.7   stress-io2-100s-1.prof.csv    -0.932507
# 176            0.7   stress-io1-100s-2.prof.csv    -0.906477
# 177            0.7  stress-cpu3-100s-1.prof.csv    -0.912515
# 178            0.7  stress-cpu2-100s-1.prof.csv    -0.918772
# 179            0.7      gzip-webster-1.prof.csv    -0.960059
# 180            0.7       ffmpeg-360p-1.prof.csv    -0.871757
# 181            0.7  stress-cpu1-100s-2.prof.csv    -0.901968
# 182            2.0      bzip2-enwik8-2.prof.csv    -0.957789
# 183            2.0     bzip2-webster-2.prof.csv    -0.959047
# 184            2.0   stress-io1-100s-1.prof.csv    -0.955055
# 185            2.0      bzip2-enwik8-1.prof.csv    -0.954614
# 186            2.0      gzip-webster-2.prof.csv    -0.987405
# 187            2.0  stress-cpu3-100s-2.prof.csv    -0.919923
# 188            2.0  stress-cpu1-100s-1.prof.csv    -0.924315
# 189            2.0       gzip-enwik8-2.prof.csv    -0.938525
# 190            2.0       ffmpeg-360p-2.prof.csv    -0.883034
# 191            2.0  stress-cpu4-100s-1.prof.csv    -0.931582
# 192            2.0   stress-io2-100s-2.prof.csv    -0.891694
# 193            2.0   stress-io3-100s-1.prof.csv    -0.906287
# 194            2.0   stress-io4-100s-1.prof.csv    -0.915978
# 195            2.0   stress-io4-100s-2.prof.csv    -0.961005
# 196            2.0       gzip-enwik8-1.prof.csv    -0.946302
# 197            2.0  stress-cpu2-100s-2.prof.csv    -0.944677
# 198            2.0  stress-cpu4-100s-2.prof.csv    -0.922222
# 199            2.0     bzip2-webster-1.prof.csv    -0.987400
# 200            2.0   stress-io3-100s-2.prof.csv    -0.924665
# 201            2.0   stress-io2-100s-1.prof.csv    -0.931580
# 202            2.0   stress-io1-100s-2.prof.csv    -0.924185
# 203            2.0  stress-cpu3-100s-1.prof.csv    -0.914980
# 204            2.0  stress-cpu2-100s-1.prof.csv    -0.911948
# 205            2.0      gzip-webster-1.prof.csv    -0.994661
# 206            2.0       ffmpeg-360p-1.prof.csv    -0.882545
# 207            2.0  stress-cpu1-100s-2.prof.csv    -0.895151
# 208            1.4      bzip2-enwik8-2.prof.csv    -0.911749
# 209            1.4     bzip2-webster-2.prof.csv    -0.983724
# 210            1.4   stress-io1-100s-1.prof.csv    -0.990440
# 211            1.4      bzip2-enwik8-1.prof.csv    -0.944875
# 212            1.4      gzip-webster-2.prof.csv    -0.992010
# 213            1.4  stress-cpu3-100s-2.prof.csv    -0.989471
# 214            1.4  stress-cpu1-100s-1.prof.csv    -0.987977
# 215            1.4       gzip-enwik8-2.prof.csv    -0.994643
# 216            1.4       ffmpeg-360p-2.prof.csv    -0.764321
# 217            1.4  stress-cpu4-100s-1.prof.csv    -0.966948
# 218            1.4   stress-io2-100s-2.prof.csv    -0.980228
# 219            1.4   stress-io3-100s-1.prof.csv    -0.917312
# 220            1.4   stress-io4-100s-1.prof.csv    -0.941890
# 221            1.4   stress-io4-100s-2.prof.csv    -0.986892
# 222            1.4       gzip-enwik8-1.prof.csv    -0.968528
# 223            1.4  stress-cpu2-100s-2.prof.csv    -0.967788
# 224            1.4  stress-cpu4-100s-2.prof.csv    -0.938184
# 225            1.4     bzip2-webster-1.prof.csv    -0.978873
# 226            1.4   stress-io3-100s-2.prof.csv    -0.993250
# 227            1.4   stress-io2-100s-1.prof.csv    -0.931667
# 228            1.4   stress-io1-100s-2.prof.csv    -0.994720
# 229            1.4  stress-cpu3-100s-1.prof.csv    -0.956332
# 230            1.4  stress-cpu2-100s-1.prof.csv    -0.970980
# 231            1.4      gzip-webster-1.prof.csv    -0.997982
# 232            1.4       ffmpeg-360p-1.prof.csv    -0.738333
# 233            1.4  stress-cpu1-100s-2.prof.csv    -0.959710
# 234            1.1      bzip2-enwik8-2.prof.csv    -0.950118
# 235            1.1     bzip2-webster-2.prof.csv    -0.957717
# 236            1.1   stress-io1-100s-1.prof.csv    -0.916112
# 237            1.1      bzip2-enwik8-1.prof.csv    -0.914317
# 238            1.1      gzip-webster-2.prof.csv    -0.975941
# 239            1.1  stress-cpu3-100s-2.prof.csv    -0.937652
# 240            1.1  stress-cpu1-100s-1.prof.csv    -0.934701
# 241            1.1       gzip-enwik8-2.prof.csv    -0.960867
# 242            1.1       ffmpeg-360p-2.prof.csv    -0.890123
# 243            1.1  stress-cpu4-100s-1.prof.csv    -0.884486
# 244            1.1   stress-io2-100s-2.prof.csv    -0.926408
# 245            1.1   stress-io3-100s-1.prof.csv    -0.949864
# 246            1.1   stress-io4-100s-1.prof.csv    -0.930393
# 247            1.1   stress-io4-100s-2.prof.csv    -0.939371
# 248            1.1       gzip-enwik8-1.prof.csv    -0.964000
# 249            1.1  stress-cpu2-100s-2.prof.csv    -0.881737
# 250            1.1  stress-cpu4-100s-2.prof.csv    -0.898204
# 251            1.1     bzip2-webster-1.prof.csv    -0.960414
# 252            1.1   stress-io3-100s-2.prof.csv    -0.936436
# 253            1.1   stress-io2-100s-1.prof.csv    -0.903584
# 254            1.1   stress-io1-100s-2.prof.csv    -0.929456
# 255            1.1  stress-cpu3-100s-1.prof.csv    -0.871193
# 256            1.1  stress-cpu2-100s-1.prof.csv    -0.951852
# 257            1.1      gzip-webster-1.prof.csv    -0.967517
# 258            1.1       ffmpeg-360p-1.prof.csv    -0.850925
# 259            1.1  stress-cpu1-100s-2.prof.csv    -0.890192
# 260            1.7      bzip2-enwik8-2.prof.csv    -0.952317
# 261            1.7     bzip2-webster-2.prof.csv    -0.970793
# 262            1.7   stress-io1-100s-1.prof.csv    -0.891779
# 263            1.7      bzip2-enwik8-1.prof.csv    -0.951168
# 264            1.7      gzip-webster-2.prof.csv    -0.968485
# 265            1.7  stress-cpu3-100s-2.prof.csv    -0.903584
# 266            1.7  stress-cpu1-100s-1.prof.csv    -0.902745
# 267            1.7       gzip-enwik8-2.prof.csv    -0.962058
# 268            1.7       ffmpeg-360p-2.prof.csv    -0.902758
# 269            1.7  stress-cpu4-100s-1.prof.csv    -0.961289
# 270            1.7   stress-io2-100s-2.prof.csv    -0.934695
# 271            1.7   stress-io3-100s-1.prof.csv    -0.956665
# 272            1.7   stress-io4-100s-1.prof.csv    -0.940589
# 273            1.7   stress-io4-100s-2.prof.csv    -0.912351
# 274            1.7       gzip-enwik8-1.prof.csv    -0.970617
# 275            1.7  stress-cpu2-100s-2.prof.csv    -0.921802
# 276            1.7  stress-cpu4-100s-2.prof.csv    -0.937935
# 277            1.7     bzip2-webster-1.prof.csv    -0.961935
# 278            1.7   stress-io3-100s-2.prof.csv    -0.915242
# 279            1.7   stress-io2-100s-1.prof.csv    -0.925692
# 280            1.7   stress-io1-100s-2.prof.csv    -0.891586
# 281            1.7  stress-cpu3-100s-1.prof.csv    -0.923516
# 282            1.7  stress-cpu2-100s-1.prof.csv    -0.951877
# 283            1.7      gzip-webster-1.prof.csv    -0.966839
# 284            1.7       ffmpeg-360p-1.prof.csv    -0.889331
# 285            1.7  stress-cpu1-100s-2.prof.csv    -0.952415
# 286            0.7      bzip2-enwik8-2.prof.csv    -0.980814
# 287            0.7     bzip2-webster-2.prof.csv    -0.987378
# 288            0.7   stress-io1-100s-1.prof.csv    -0.993944
# 289            0.7      bzip2-enwik8-1.prof.csv    -0.881109
# 290            0.7      gzip-webster-2.prof.csv    -0.994531
# 291            0.7  stress-cpu3-100s-2.prof.csv    -0.916452
# 292            0.7  stress-cpu1-100s-1.prof.csv    -0.963293
# 293            0.7       gzip-enwik8-2.prof.csv    -0.947112
# 294            0.7       ffmpeg-360p-2.prof.csv    -0.794712
# 295            0.7  stress-cpu4-100s-1.prof.csv    -0.931327
# 296            0.7   stress-io2-100s-2.prof.csv    -0.993578
# 297            0.7   stress-io3-100s-1.prof.csv    -0.992592
# 298            0.7   stress-io4-100s-1.prof.csv    -0.989437
# 299            0.7   stress-io4-100s-2.prof.csv    -0.937159
# 300            0.7       gzip-enwik8-1.prof.csv    -0.948391
# 301            0.7  stress-cpu2-100s-2.prof.csv    -0.984566
# 302            0.7  stress-cpu4-100s-2.prof.csv    -0.979620
# 303            0.7     bzip2-webster-1.prof.csv    -0.984648
# 304            0.7   stress-io3-100s-2.prof.csv    -0.991123
# 305            0.7   stress-io2-100s-1.prof.csv    -0.985600
# 306            0.7   stress-io1-100s-2.prof.csv    -0.993188
# 307            0.7  stress-cpu3-100s-1.prof.csv    -0.943644
# 308            0.7  stress-cpu2-100s-1.prof.csv    -0.977048
# 309            0.7      gzip-webster-1.prof.csv    -0.982332
# 310            0.7       ffmpeg-360p-1.prof.csv    -0.814499
# 311            0.7  stress-cpu1-100s-2.prof.csv    -0.955399
# 312            1.1      bzip2-enwik8-2.prof.csv    -0.983533
# 313            1.1     bzip2-webster-2.prof.csv    -0.988083
# 314            1.1   stress-io1-100s-1.prof.csv    -0.991567
# 315            1.1      bzip2-enwik8-1.prof.csv    -0.902468
# 316            1.1      gzip-webster-2.prof.csv    -0.993961
# 317            1.1  stress-cpu3-100s-2.prof.csv    -0.951749
# 318            1.1  stress-cpu1-100s-1.prof.csv    -0.923352
# 319            1.1       gzip-enwik8-2.prof.csv    -0.969711
# 320            1.1       ffmpeg-360p-2.prof.csv    -0.761188
# 321            1.1  stress-cpu4-100s-1.prof.csv    -0.941277
# 322            1.1   stress-io2-100s-2.prof.csv    -0.911505
# 323            1.1   stress-io3-100s-1.prof.csv    -0.973540
# 324            1.1   stress-io4-100s-1.prof.csv    -0.991810
# 325            1.1   stress-io4-100s-2.prof.csv    -0.994102
# 326            1.1       gzip-enwik8-1.prof.csv    -0.953819
# 327            1.1  stress-cpu2-100s-2.prof.csv    -0.962823
# 328            1.1  stress-cpu4-100s-2.prof.csv    -0.928609
# 329            1.1     bzip2-webster-1.prof.csv    -0.970865
# 330            1.1   stress-io3-100s-2.prof.csv    -0.989629
# 331            1.1   stress-io2-100s-1.prof.csv    -0.995054
# 332            1.1   stress-io1-100s-2.prof.csv    -0.934037
# 333            1.1  stress-cpu3-100s-1.prof.csv    -0.977427
# 334            1.1  stress-cpu2-100s-1.prof.csv    -0.977880
# 335            1.1      gzip-webster-1.prof.csv    -0.989375
# 336            1.1       ffmpeg-360p-1.prof.csv    -0.856944
# 337            1.1  stress-cpu1-100s-2.prof.csv    -0.929295
# 338            1.9      bzip2-enwik8-2.prof.csv    -0.950864
# 339            1.9     bzip2-webster-2.prof.csv    -0.961964
# 340            1.9   stress-io1-100s-1.prof.csv    -0.884993
# 341            1.9      bzip2-enwik8-1.prof.csv    -0.921976
# 342            1.9      gzip-webster-2.prof.csv    -0.985551
# 343            1.9  stress-cpu3-100s-2.prof.csv    -0.916249
# 344            1.9  stress-cpu1-100s-1.prof.csv    -0.874915
# 345            1.9       gzip-enwik8-2.prof.csv    -0.956188
# 346            1.9       ffmpeg-360p-2.prof.csv    -0.872044
# 347            1.9  stress-cpu4-100s-1.prof.csv    -0.901642
# 348            1.9   stress-io2-100s-2.prof.csv    -0.931874
# 349            1.9   stress-io3-100s-1.prof.csv    -0.942146
# 350            1.9   stress-io4-100s-1.prof.csv    -0.916345
# 351            1.9   stress-io4-100s-2.prof.csv    -0.914785
# 352            1.9       gzip-enwik8-1.prof.csv    -0.991672
# 353            1.9  stress-cpu2-100s-2.prof.csv    -0.941840
# 354            1.9  stress-cpu4-100s-2.prof.csv    -0.958659
# 355            1.9     bzip2-webster-1.prof.csv    -0.955691
# 356            1.9   stress-io3-100s-2.prof.csv    -0.932839
# 357            1.9   stress-io2-100s-1.prof.csv    -0.942485
# 358            1.9   stress-io1-100s-2.prof.csv    -0.948359
# 359            1.9  stress-cpu3-100s-1.prof.csv    -0.947993
# 360            1.9  stress-cpu2-100s-1.prof.csv    -0.925893
# 361            1.9      gzip-webster-1.prof.csv    -0.956595
# 362            1.9       ffmpeg-360p-1.prof.csv    -0.881581
# 363            1.9  stress-cpu1-100s-2.prof.csv    -0.942531
# 364            0.6   stress-io1-100s-1.prof.csv    -0.992938
# 365            0.6      bzip2-enwik8-1.prof.csv    -0.889824
# 366            0.6  stress-cpu1-100s-1.prof.csv    -0.953772
# 367            0.6  stress-cpu4-100s-1.prof.csv    -0.904045
# 368            0.6   stress-io3-100s-1.prof.csv    -0.928105
# 369            0.6   stress-io4-100s-1.prof.csv    -0.989607
# 370            0.6       gzip-enwik8-1.prof.csv    -0.992938
# 371            0.6     bzip2-webster-1.prof.csv    -0.985664
# 372            0.6   stress-io2-100s-1.prof.csv    -0.981112
# 373            0.6  stress-cpu3-100s-1.prof.csv    -0.918804
# 374            0.6  stress-cpu2-100s-1.prof.csv    -0.917191
# 375            0.6      gzip-webster-1.prof.csv    -0.986747
# 376            0.6       ffmpeg-360p-1.prof.csv    -0.840849
# 377            1.3      bzip2-enwik8-2.prof.csv    -0.986963
# 378            1.3     bzip2-webster-2.prof.csv    -0.972595
# 379            1.3   stress-io1-100s-1.prof.csv    -0.994204
# 380            1.3      bzip2-enwik8-1.prof.csv    -0.918605
# 381            1.3      gzip-webster-2.prof.csv    -0.995700
# 382            1.3  stress-cpu3-100s-2.prof.csv    -0.925167
# 383            1.3  stress-cpu1-100s-1.prof.csv    -0.913945
# 384            1.3       gzip-enwik8-2.prof.csv    -0.994137
# 385            1.3       ffmpeg-360p-2.prof.csv    -0.832844
# 386            1.3  stress-cpu4-100s-1.prof.csv    -0.978803
# 387            1.3   stress-io2-100s-2.prof.csv    -0.982119
# 388            1.3   stress-io3-100s-1.prof.csv    -0.991328
# 389            1.3   stress-io4-100s-1.prof.csv    -0.993081
# 390            1.3   stress-io4-100s-2.prof.csv    -0.988707
# 391            1.3       gzip-enwik8-1.prof.csv    -0.980959
# 392            1.3  stress-cpu2-100s-2.prof.csv    -0.935278
# 393            1.3  stress-cpu4-100s-2.prof.csv    -0.949216
# 394            1.3     bzip2-webster-1.prof.csv    -0.980334
# 395            1.3   stress-io3-100s-2.prof.csv    -0.959523
# 396            1.3   stress-io2-100s-1.prof.csv    -0.981257
# 397            1.3   stress-io1-100s-2.prof.csv    -0.993118
# 398            1.3  stress-cpu3-100s-1.prof.csv    -0.932014
# 399            1.3  stress-cpu2-100s-1.prof.csv    -0.968462
# 400            1.3      gzip-webster-1.prof.csv    -0.996723
# 401            1.3       ffmpeg-360p-1.prof.csv    -0.848765
# 402            1.3  stress-cpu1-100s-2.prof.csv    -0.984334
# 403            0.3   stress-io1-100s-1.prof.csv    -0.991652
# 404            0.3      bzip2-enwik8-1.prof.csv    -0.984181
# 405            0.3  stress-cpu1-100s-1.prof.csv    -0.987033
# 406            0.3  stress-cpu4-100s-1.prof.csv    -0.912324
# 407            0.3   stress-io3-100s-1.prof.csv    -0.989393
# 408            0.3   stress-io4-100s-1.prof.csv    -0.990981
# 409            0.3       gzip-enwik8-1.prof.csv    -0.925158
# 410            0.3     bzip2-webster-1.prof.csv    -0.984144
# 411            0.3   stress-io2-100s-1.prof.csv    -0.991773
# 412            0.3  stress-cpu3-100s-1.prof.csv    -0.969984
# 413            0.3  stress-cpu2-100s-1.prof.csv    -0.974965
# 414            0.3      gzip-webster-1.prof.csv    -0.985738
# 415            0.3       ffmpeg-360p-1.prof.csv    -0.669412
# 416            0.9      bzip2-enwik8-2.prof.csv    -0.938778
# 417            0.9     bzip2-webster-2.prof.csv    -0.962321
# 418            0.9   stress-io1-100s-1.prof.csv    -0.945975
# 419            0.9      bzip2-enwik8-1.prof.csv    -0.894340
# 420            0.9      gzip-webster-2.prof.csv    -0.970062
# 421            0.9  stress-cpu3-100s-2.prof.csv    -0.916355
# 422            0.9  stress-cpu1-100s-1.prof.csv    -0.913201
# 423            0.9       gzip-enwik8-2.prof.csv    -0.930294
# 424            0.9       ffmpeg-360p-2.prof.csv    -0.888544
# 425            0.9  stress-cpu4-100s-1.prof.csv    -0.935161
# 426            0.9   stress-io2-100s-2.prof.csv    -0.941622
# 427            0.9   stress-io3-100s-1.prof.csv    -0.944810
# 428            0.9   stress-io4-100s-1.prof.csv    -0.914951
# 429            0.9   stress-io4-100s-2.prof.csv    -0.933317
# 430            0.9       gzip-enwik8-1.prof.csv    -0.958341
# 431            0.9  stress-cpu2-100s-2.prof.csv    -0.959228
# 432            0.9  stress-cpu4-100s-2.prof.csv    -0.940862
# 433            0.9     bzip2-webster-1.prof.csv    -0.936765
# 434            0.9   stress-io3-100s-2.prof.csv    -0.931924
# 435            0.9   stress-io2-100s-1.prof.csv    -0.892760
# 436            0.9   stress-io1-100s-2.prof.csv    -0.912850
# 437            0.9  stress-cpu3-100s-1.prof.csv    -0.897965
# 438            0.9  stress-cpu2-100s-1.prof.csv    -0.888621
# 439            0.9      gzip-webster-1.prof.csv    -0.966014
# 440            0.9       ffmpeg-360p-1.prof.csv    -0.871473
# 441            0.9  stress-cpu1-100s-2.prof.csv    -0.949405
# 442            0.5   stress-io1-100s-1.prof.csv    -0.941332
# 443            0.5      bzip2-enwik8-1.prof.csv    -0.894608
# 444            0.5  stress-cpu1-100s-1.prof.csv    -0.916396
# 445            0.5  stress-cpu4-100s-1.prof.csv    -0.915283
# 446            0.5   stress-io3-100s-1.prof.csv    -0.940623
# 447            0.5   stress-io4-100s-1.prof.csv    -0.951035
# 448            0.5       gzip-enwik8-1.prof.csv    -0.911041
# 449            0.5     bzip2-webster-1.prof.csv    -0.950117
# 450            0.5   stress-io2-100s-1.prof.csv    -0.918552
# 451            0.5  stress-cpu3-100s-1.prof.csv    -0.889737
# 452            0.5  stress-cpu2-100s-1.prof.csv    -0.916349
# 453            0.5      gzip-webster-1.prof.csv    -0.955407
# 454            0.5       ffmpeg-360p-1.prof.csv    -0.884506
# 455            0.8      bzip2-enwik8-2.prof.csv    -0.928185
# 456            0.8     bzip2-webster-2.prof.csv    -0.958465
# 457            0.8   stress-io1-100s-1.prof.csv    -0.915877
# 458            0.8      bzip2-enwik8-1.prof.csv    -0.929742
# 459            0.8      gzip-webster-2.prof.csv    -0.963740
# 460            0.8  stress-cpu3-100s-2.prof.csv    -0.873398
# 461            0.8  stress-cpu1-100s-1.prof.csv    -0.920811
# 462            0.8       gzip-enwik8-2.prof.csv    -0.923192
# 463            0.8       ffmpeg-360p-2.prof.csv    -0.874597
# 464            0.8  stress-cpu4-100s-1.prof.csv    -0.957542
# 465            0.8   stress-io2-100s-2.prof.csv    -0.903464
# 466            0.8   stress-io3-100s-1.prof.csv    -0.904304
# 467            0.8   stress-io4-100s-1.prof.csv    -0.942344
# 468            0.8   stress-io4-100s-2.prof.csv    -0.937439
# 469            0.8       gzip-enwik8-1.prof.csv    -0.935394
# 470            0.8  stress-cpu2-100s-2.prof.csv    -0.892067
# 471            0.8  stress-cpu4-100s-2.prof.csv    -0.905467
# 472            0.8     bzip2-webster-1.prof.csv    -0.952765
# 473            0.8   stress-io3-100s-2.prof.csv    -0.924422
# 474            0.8   stress-io2-100s-1.prof.csv    -0.923107
# 475            0.8   stress-io1-100s-2.prof.csv    -0.902236
# 476            0.8  stress-cpu3-100s-1.prof.csv    -0.877105
# 477            0.8  stress-cpu2-100s-1.prof.csv    -0.920265
# 478            0.8      gzip-webster-1.prof.csv    -0.993697
# 479            0.8       ffmpeg-360p-1.prof.csv    -0.884489
# 480            0.8  stress-cpu1-100s-2.prof.csv    -0.907250
# 481            1.8      bzip2-enwik8-2.prof.csv    -0.974165
# 482            1.8     bzip2-webster-2.prof.csv    -0.973269
# 483            1.8   stress-io1-100s-1.prof.csv    -0.892908
# 484            1.8      bzip2-enwik8-1.prof.csv    -0.918395
# 485            1.8      gzip-webster-2.prof.csv    -0.973303
# 486            1.8  stress-cpu3-100s-2.prof.csv    -0.943330
# 487            1.8  stress-cpu1-100s-1.prof.csv    -0.955511
# 488            1.8       gzip-enwik8-2.prof.csv    -0.938483
# 489            1.8       ffmpeg-360p-2.prof.csv    -0.881631
# 490            1.8  stress-cpu4-100s-1.prof.csv    -0.932788
# 491            1.8   stress-io2-100s-2.prof.csv    -0.935263
# 492            1.8   stress-io3-100s-1.prof.csv    -0.937134
# 493            1.8   stress-io4-100s-1.prof.csv    -0.935829
# 494            1.8   stress-io4-100s-2.prof.csv    -0.944626
# 495            1.8       gzip-enwik8-1.prof.csv    -0.970785
# 496            1.8  stress-cpu2-100s-2.prof.csv    -0.921875
# 497            1.8  stress-cpu4-100s-2.prof.csv    -0.903788
# 498            1.8     bzip2-webster-1.prof.csv    -0.974427
# 499            1.8   stress-io3-100s-2.prof.csv    -0.934186
# 500            1.8   stress-io2-100s-1.prof.csv    -0.924486
# 501            1.8   stress-io1-100s-2.prof.csv    -0.915966
# 502            1.8  stress-cpu3-100s-1.prof.csv    -0.895195
# 503            1.8  stress-cpu2-100s-1.prof.csv    -0.913092
# 504            1.8      gzip-webster-1.prof.csv    -0.962279
# 505            1.8       ffmpeg-360p-1.prof.csv    -0.883743
# 506            1.8  stress-cpu1-100s-2.prof.csv    -0.883479
# 507            1.3      bzip2-enwik8-2.prof.csv    -0.913969
# 508            1.3     bzip2-webster-2.prof.csv    -0.977676
# 509            1.3   stress-io1-100s-1.prof.csv    -0.905512
# 510            1.3      bzip2-enwik8-1.prof.csv    -0.914788
# 511            1.3      gzip-webster-2.prof.csv    -0.958650
# 512            1.3  stress-cpu3-100s-2.prof.csv    -0.910641
# 513            1.3  stress-cpu1-100s-1.prof.csv    -0.944508
# 514            1.3       gzip-enwik8-2.prof.csv    -0.933894
# 515            1.3       ffmpeg-360p-2.prof.csv    -0.886781
# 516            1.3  stress-cpu4-100s-1.prof.csv    -0.931059
# 517            1.3   stress-io2-100s-2.prof.csv    -0.904710
# 518            1.3   stress-io3-100s-1.prof.csv    -0.898210
# 519            1.3   stress-io4-100s-1.prof.csv    -0.951001
# 520            1.3   stress-io4-100s-2.prof.csv    -0.870922
# 521            1.3       gzip-enwik8-1.prof.csv    -0.935518
# 522            1.3  stress-cpu2-100s-2.prof.csv    -0.906609
# 523            1.3  stress-cpu4-100s-2.prof.csv    -0.926559
# 524            1.3     bzip2-webster-1.prof.csv    -0.939802
# 525            1.3   stress-io3-100s-2.prof.csv    -0.954700
# 526            1.3   stress-io2-100s-1.prof.csv    -0.947429
# 527            1.3   stress-io1-100s-2.prof.csv    -0.905435
# 528            1.3  stress-cpu3-100s-1.prof.csv    -0.923842
# 529            1.3  stress-cpu2-100s-1.prof.csv    -0.933131
# 530            1.3      gzip-webster-1.prof.csv    -0.962671
# 531            1.3       ffmpeg-360p-1.prof.csv    -0.782691
# 532            1.3  stress-cpu1-100s-2.prof.csv    -0.862885
# 533            0.9      bzip2-enwik8-2.prof.csv    -0.986037
# 534            0.9     bzip2-webster-2.prof.csv    -0.986261
# 535            0.9   stress-io1-100s-1.prof.csv    -0.967045
# 536            0.9      bzip2-enwik8-1.prof.csv    -0.914087
# 537            0.9      gzip-webster-2.prof.csv    -0.977607
# 538            0.9  stress-cpu3-100s-2.prof.csv    -0.923802
# 539            0.9  stress-cpu1-100s-1.prof.csv    -0.974975
# 540            0.9       gzip-enwik8-2.prof.csv    -0.953423
# 541            0.9       ffmpeg-360p-2.prof.csv    -0.758798
# 542            0.9  stress-cpu4-100s-1.prof.csv    -0.982005
# 543            0.9   stress-io2-100s-2.prof.csv    -0.959209
# 544            0.9   stress-io3-100s-1.prof.csv    -0.993752
# 545            0.9   stress-io4-100s-1.prof.csv    -0.982267
# 546            0.9   stress-io4-100s-2.prof.csv    -0.921305
# 547            0.9       gzip-enwik8-1.prof.csv    -0.952510
# 548            0.9  stress-cpu2-100s-2.prof.csv    -0.911084
# 549            0.9  stress-cpu4-100s-2.prof.csv    -0.919560
# 550            0.9     bzip2-webster-1.prof.csv    -0.945557
# 551            0.9   stress-io3-100s-2.prof.csv    -0.987594
# 552            0.9   stress-io2-100s-1.prof.csv    -0.977689
# 553            0.9   stress-io1-100s-2.prof.csv    -0.955518
# 554            0.9  stress-cpu3-100s-1.prof.csv    -0.922130
# 555            0.9  stress-cpu2-100s-1.prof.csv    -0.921390
# 556            0.9      gzip-webster-1.prof.csv    -0.967832
# 557            0.9       ffmpeg-360p-1.prof.csv    -0.834180
# 558            0.9  stress-cpu1-100s-2.prof.csv    -0.928579
# 559            1.2      bzip2-enwik8-2.prof.csv    -0.958010
# 560            1.2     bzip2-webster-2.prof.csv    -0.950673
# 561            1.2   stress-io1-100s-1.prof.csv    -0.911684
# 562            1.2      bzip2-enwik8-1.prof.csv    -0.938690
# 563            1.2      gzip-webster-2.prof.csv    -0.965029
# 564            1.2  stress-cpu3-100s-2.prof.csv    -0.938990
# 565            1.2  stress-cpu1-100s-1.prof.csv    -0.923688
# 566            1.2       gzip-enwik8-2.prof.csv    -0.964295
# 567            1.2       ffmpeg-360p-2.prof.csv    -0.912481
# 568            1.2  stress-cpu4-100s-1.prof.csv    -0.936932
# 569            1.2   stress-io2-100s-2.prof.csv    -0.916275
# 570            1.2   stress-io3-100s-1.prof.csv    -0.925109
# 571            1.2   stress-io4-100s-1.prof.csv    -0.907186
# 572            1.2   stress-io4-100s-2.prof.csv    -0.927407
# 573            1.2       gzip-enwik8-1.prof.csv    -0.925764
# 574            1.2  stress-cpu2-100s-2.prof.csv    -0.957052
# 575            1.2  stress-cpu4-100s-2.prof.csv    -0.916063
# 576            1.2     bzip2-webster-1.prof.csv    -0.961195
# 577            1.2   stress-io3-100s-2.prof.csv    -0.920775
# 578            1.2   stress-io2-100s-1.prof.csv    -0.896827
# 579            1.2   stress-io1-100s-2.prof.csv    -0.895951
# 580            1.2  stress-cpu3-100s-1.prof.csv    -0.897977
# 581            1.2  stress-cpu2-100s-1.prof.csv    -0.936717
# 582            1.2      gzip-webster-1.prof.csv    -0.950740
# 583            1.2       ffmpeg-360p-1.prof.csv    -0.901846
# 584            1.2  stress-cpu1-100s-2.prof.csv    -0.945758
# 585            0.6      bzip2-enwik8-2.prof.csv    -0.912284
# 586            0.6     bzip2-webster-2.prof.csv    -0.922117
# 587            0.6   stress-io1-100s-1.prof.csv    -0.938886
# 588            0.6      bzip2-enwik8-1.prof.csv    -0.955948
# 589            0.6      gzip-webster-2.prof.csv    -0.940765
# 590            0.6  stress-cpu3-100s-2.prof.csv    -0.869113
# 591            0.6  stress-cpu1-100s-1.prof.csv    -0.940463
# 592            0.6       gzip-enwik8-2.prof.csv    -0.955338
# 593            0.6       ffmpeg-360p-2.prof.csv    -0.890297
# 594            0.6  stress-cpu4-100s-1.prof.csv    -0.902819
# 595            0.6   stress-io2-100s-2.prof.csv    -0.924142
# 596            0.6   stress-io3-100s-1.prof.csv    -0.927940
# 597            0.6   stress-io4-100s-1.prof.csv    -0.933370
# 598            0.6   stress-io4-100s-2.prof.csv    -0.933541
# 599            0.6       gzip-enwik8-1.prof.csv    -0.906618
# 600            0.6  stress-cpu2-100s-2.prof.csv    -0.893217
# 601            0.6  stress-cpu4-100s-2.prof.csv    -0.863226
# 602            0.6     bzip2-webster-1.prof.csv    -0.926289
# 603            0.6   stress-io3-100s-2.prof.csv    -0.943581
# 604            0.6   stress-io2-100s-1.prof.csv    -0.928583
# 605            0.6   stress-io1-100s-2.prof.csv    -0.941494
# 606            0.6  stress-cpu3-100s-1.prof.csv    -0.938532
# 607            0.6  stress-cpu2-100s-1.prof.csv    -0.946552
# 608            0.6      gzip-webster-1.prof.csv    -0.936607
# 609            0.6       ffmpeg-360p-1.prof.csv    -0.875302
# 610            0.6  stress-cpu1-100s-2.prof.csv    -0.913802
# 611            1.0      bzip2-enwik8-2.prof.csv    -0.941727
# 612            1.0     bzip2-webster-2.prof.csv    -0.960324
# 613            1.0   stress-io1-100s-1.prof.csv    -0.920978
# 614            1.0      bzip2-enwik8-1.prof.csv    -0.945488
# 615            1.0      gzip-webster-2.prof.csv    -0.968787
# 616            1.0  stress-cpu3-100s-2.prof.csv    -0.934909
# 617            1.0  stress-cpu1-100s-1.prof.csv    -0.924365
# 618            1.0       gzip-enwik8-2.prof.csv    -0.957163
# 619            1.0       ffmpeg-360p-2.prof.csv    -0.875914
# 620            1.0  stress-cpu4-100s-1.prof.csv    -0.916237
# 621            1.0   stress-io2-100s-2.prof.csv    -0.931426
# 622            1.0   stress-io3-100s-1.prof.csv    -0.933144
# 623            1.0   stress-io4-100s-1.prof.csv    -0.921812
# 624            1.0   stress-io4-100s-2.prof.csv    -0.937784
# 625            1.0       gzip-enwik8-1.prof.csv    -0.951528
# 626            1.0  stress-cpu2-100s-2.prof.csv    -0.905896
# 627            1.0  stress-cpu4-100s-2.prof.csv    -0.867183
# 628            1.0     bzip2-webster-1.prof.csv    -0.943103
# 629            1.0   stress-io3-100s-2.prof.csv    -0.958194
# 630            1.0   stress-io2-100s-1.prof.csv    -0.906361
# 631            1.0   stress-io1-100s-2.prof.csv    -0.928133
# 632            1.0  stress-cpu3-100s-1.prof.csv    -0.911657
# 633            1.0  stress-cpu2-100s-1.prof.csv    -0.926198
# 634            1.0      gzip-webster-1.prof.csv    -0.982369
# 635            1.0       ffmpeg-360p-1.prof.csv    -0.874607
# 636            1.0  stress-cpu1-100s-2.prof.csv    -0.943489
# 637            0.2   stress-io1-100s-1.prof.csv    -0.983140
# 638            0.2      bzip2-enwik8-1.prof.csv    -0.860986
# 639            0.2  stress-cpu1-100s-1.prof.csv    -0.961567
# 640            0.2  stress-cpu4-100s-1.prof.csv    -0.872272
# 641            0.2   stress-io3-100s-1.prof.csv    -0.888084
# 642            0.2   stress-io4-100s-1.prof.csv    -0.984784
# 643            0.2       gzip-enwik8-1.prof.csv    -0.980486
# 644            0.2     bzip2-webster-1.prof.csv    -0.978315
# 645            0.2   stress-io2-100s-1.prof.csv    -0.988179
# 646            0.2  stress-cpu3-100s-1.prof.csv    -0.976995
# 647            0.2  stress-cpu2-100s-1.prof.csv    -0.932481
# 648            0.2      gzip-webster-1.prof.csv    -0.986970
# 649            0.2       ffmpeg-360p-1.prof.csv    -0.665649
# 650            1.6      bzip2-enwik8-2.prof.csv    -0.947911
# 651            1.6     bzip2-webster-2.prof.csv    -0.967372
# 652            1.6   stress-io1-100s-1.prof.csv    -0.892581
# 653            1.6      bzip2-enwik8-1.prof.csv    -0.912915
# 654            1.6      gzip-webster-2.prof.csv    -0.970416
# 655            1.6  stress-cpu3-100s-2.prof.csv    -0.910592
# 656            1.6  stress-cpu1-100s-1.prof.csv    -0.881607
# 657            1.6       gzip-enwik8-2.prof.csv    -0.962592
# 658            1.6       ffmpeg-360p-2.prof.csv    -0.892869
# 659            1.6  stress-cpu4-100s-1.prof.csv    -0.916695
# 660            1.6   stress-io2-100s-2.prof.csv    -0.924784
# 661            1.6   stress-io3-100s-1.prof.csv    -0.912863
# 662            1.6   stress-io4-100s-1.prof.csv    -0.925792
# 663            1.6   stress-io4-100s-2.prof.csv    -0.950390
# 664            1.6       gzip-enwik8-1.prof.csv    -0.948599
# 665            1.6  stress-cpu2-100s-2.prof.csv    -0.926760
# 666            1.6  stress-cpu4-100s-2.prof.csv    -0.927929
# 667            1.6     bzip2-webster-1.prof.csv    -0.967195
# 668            1.6   stress-io3-100s-2.prof.csv    -0.923084
# 669            1.6   stress-io2-100s-1.prof.csv    -0.942983
# 670            1.6   stress-io1-100s-2.prof.csv    -0.913773
# 671            1.6  stress-cpu3-100s-1.prof.csv    -0.907210
# 672            1.6  stress-cpu2-100s-1.prof.csv    -0.906939
# 673            1.6      gzip-webster-1.prof.csv    -0.982388
# 674            1.6       ffmpeg-360p-1.prof.csv    -0.883524
# 675            1.6  stress-cpu1-100s-2.prof.csv    -0.973526
# 676            1.0      bzip2-enwik8-2.prof.csv    -0.954046
# 677            1.0     bzip2-webster-2.prof.csv    -0.986153
# 678            1.0   stress-io1-100s-1.prof.csv    -0.988511
# 679            1.0      bzip2-enwik8-1.prof.csv    -0.986633
# 680            1.0      gzip-webster-2.prof.csv    -0.994003
# 681            1.0  stress-cpu3-100s-2.prof.csv    -0.919216
# 682            1.0  stress-cpu1-100s-1.prof.csv    -0.936133
# 683            1.0       gzip-enwik8-2.prof.csv    -0.973328
# 684            1.0       ffmpeg-360p-2.prof.csv    -0.857691
# 685            1.0  stress-cpu4-100s-1.prof.csv    -0.969587
# 686            1.0   stress-io2-100s-2.prof.csv    -0.985120
# 687            1.0   stress-io3-100s-1.prof.csv    -0.988953
# 688            1.0   stress-io4-100s-1.prof.csv    -0.991449
# 689            1.0   stress-io4-100s-2.prof.csv    -0.986263
# 690            1.0       gzip-enwik8-1.prof.csv    -0.994581
# 691            1.0  stress-cpu2-100s-2.prof.csv    -0.927080
# 692            1.0  stress-cpu4-100s-2.prof.csv    -0.977729
# 693            1.0     bzip2-webster-1.prof.csv    -0.985599
# 694            1.0   stress-io3-100s-2.prof.csv    -0.992852
# 695            1.0   stress-io2-100s-1.prof.csv    -0.990992
# 696            1.0   stress-io1-100s-2.prof.csv    -0.994326
# 697            1.0  stress-cpu3-100s-1.prof.csv    -0.987077
# 698            1.0  stress-cpu2-100s-1.prof.csv    -0.927863
# 699            1.0      gzip-webster-1.prof.csv    -0.996274
# 700            1.0       ffmpeg-360p-1.prof.csv    -0.826331
# 701            1.0  stress-cpu1-100s-2.prof.csv    -0.947873
# 702            0.2   stress-io1-100s-1.prof.csv    -0.958811
# 703            0.2      bzip2-enwik8-1.prof.csv    -0.932832
# 704            0.2  stress-cpu1-100s-1.prof.csv    -0.935318
# 705            0.2  stress-cpu4-100s-1.prof.csv    -0.924069
# 706            0.2   stress-io3-100s-1.prof.csv    -0.913353
# 707            0.2   stress-io4-100s-1.prof.csv    -0.923194
# 708            0.2       gzip-enwik8-1.prof.csv    -0.931352
# 709            0.2     bzip2-webster-1.prof.csv    -0.957000
# 710            0.2   stress-io2-100s-1.prof.csv    -0.931163
# 711            0.2  stress-cpu3-100s-1.prof.csv    -0.944261
# 712            0.2  stress-cpu2-100s-1.prof.csv    -0.956237
# 713            0.2      gzip-webster-1.prof.csv    -0.958320
# 714            0.2       ffmpeg-360p-1.prof.csv    -0.900582
